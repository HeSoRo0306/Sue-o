# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
tips = pd.read_csv('/home/hesoro/Data_Scientist_con_Python/Matplotlib_y_Seaborn/Sleep_health_and_lifestyle_dataset.csv')
tips.head(2)
# Out:
#    Person ID Gender  Age         Occupation  Sleep Duration  Quality of Sleep  \
# 0          1   Male   27  Software Engineer             6.1                 6
# 1          2   Male   28             Doctor             6.2                 6
#
#    Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 0                       42             6   Overweight         126/83
# 1                       60             8       Normal         125/80
#
#    Heart Rate  Daily Steps Sleep Disorder
# 0          77         4200           None
# 1          75        10000           None

# %%
sns.catplot(data=tips, x='Physical Activity Level', y='Sleep Duration', hue='Occupation', col='Sleep Disorder', dodge=False)
plt.show()

# %% [markdown]
# podemos ver que los que mas actividad fisica hacen tienden a dormir mejor, se cumple para todos exepto para los enfermeros
